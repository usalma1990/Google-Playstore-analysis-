# %%
#import necessary packages 
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("playstore_reviews.csv",index_col='App')

# %%
df.head()
# Out:
#                                                        Translated_Review  \
# App
# 10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 10 Best Foods for You    This help eating healthy exercise regular basis
# 10 Best Foods for You                                                NaN
# 10 Best Foods for You         Works great especially going grocery store
# 10 Best Foods for You                                       Best idea us
#
#                       Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# App
# 10 Best Foods for You  Positive                1.00                0.533333
# 10 Best Foods for You  Positive                0.25                0.288462
# 10 Best Foods for You       NaN                 NaN                     NaN
# 10 Best Foods for You  Positive                0.40                0.875000
# 10 Best Foods for You  Positive                1.00                0.300000

# %%
df.tail()
# Out:
#                             Translated_Review Sentiment  Sentiment_Polarity  \
# App
# Houzz Interior Design Ideas               NaN       NaN                 NaN
# Houzz Interior Design Ideas               NaN       NaN                 NaN
# Houzz Interior Design Ideas               NaN       NaN                 NaN
# Houzz Interior Design Ideas               NaN       NaN                 NaN
# Houzz Interior Design Ideas               NaN       NaN                 NaN
#
#                              Sentiment_Subjectivity
# App
# Houzz Interior Design Ideas                     NaN
# Houzz Interior Design Ideas                     NaN
# Houzz Interior Design Ideas                     NaN
# Houzz Interior Design Ideas                     NaN
# Houzz Interior Design Ideas                     NaN

# %%
df.shape
# Out:
# (64295, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64295 entries, 10 Best Foods for You to Houzz Interior Design Ideas
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Translated_Review       37427 non-null  object
#  1   Sentiment               37432 non-null  object
#  2   Sentiment_Polarity      37432 non-null  float64
#  3   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 2.5+ MB

# %%
df.dtypes
# Out:
# Translated_Review          object
# Sentiment                  object
# Sentiment_Polarity        float64
# Sentiment_Subjectivity    float64
# dtype: object

# %%
df.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count        37432.000000            37432.000000
# mean             0.182146                0.492704
# std              0.351301                0.259949
# min             -1.000000                0.000000
# 25%              0.000000                0.357143
# 50%              0.150000                0.514286
# 75%              0.400000                0.650000
# max              1.000000                1.000000

# %%
df.describe(include='object')
# Out:
#        Translated_Review Sentiment
# count              37427     37432
# unique             27994         3
# top                 Good  Positive
# freq                 247     23998

# %%
Total = df.isnull().sum().sort_values(ascending = False)          

Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending = False)   

missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])    
missing_data
# Out:
#                         Total  Percentage of Missing Values
# Translated_Review       26868                     41.788631
# Sentiment               26863                     41.780854
# Sentiment_Polarity      26863                     41.780854
# Sentiment_Subjectivity  26863                     41.780854

# %%
#Subtask 1 : Remove duplicate rows 
df.drop_duplicates(keep=False,inplace=True)

# %%
df.shape
# Out:
# (22593, 4)

# %%
Total = df.isnull().sum().sort_values(ascending = False)          

Percent = (df.isnull().sum()*100/df.isnull().count()).sort_values(ascending = False)   

missing_data = pd.concat([Total, Percent], axis = 1, keys = ['Total', 'Percentage of Missing Values'])    
missing_data
# Out:
#                         Total  Percentage of Missing Values
# Translated_Review           0                           0.0
# Sentiment                   0                           0.0
# Sentiment_Polarity          0                           0.0
# Sentiment_Subjectivity      0                           0.0

# %%
df.to_csv("cleaned_reviews_data_new.csv")

# %%
df.shape
# Out:
# (22593, 4)

# %%
df.head(10)
# Out:
#                                                                   Translated_Review  \
# App
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                Almost mobile phone
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Very effective, efficient convenient find avai...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                     Easy intuitive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                      good searching job internship
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                Not bad, price little bit expensive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                          easy use!
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室               job search results iOS e.g. security
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Well, it is also the largest human bank in Tai...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                                 So
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                 Very good job hunt
#
#                                  Sentiment  Sentiment_Polarity  \
# App
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室   Neutral            0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.626667
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.433333
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.700000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Negative           -0.112500
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.541667
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室   Neutral            0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室   Neutral            0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室   Neutral            0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室  Positive            0.910000
#
#                                   Sentiment_Subjectivity
# App
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.666667
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.833333
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.600000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.622222
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.833333
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.100000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                0.780000

# %%
df.tail(10)
# Out:
#                                                                 Translated_Review  \
# App
# Housing-Real Estate & Property  Worst app. We get nothing Time waste . They up...
# Housing-Real Estate & Property  I able set range 1cr, scroll space 0-1cr range...
# Housing-Real Estate & Property  What nonsensical app.. doesn't owner postings ...
# Housing-Real Estate & Property  No response support team. After I login, unabl...
# Housing-Real Estate & Property  Everything old stuff neither clear sold proper...
# Housing-Real Estate & Property  Most ads older many agents ..not much owner po...
# Housing-Real Estate & Property  If photos posted portal load, fit purpose. I'm...
# Housing-Real Estate & Property  Dumb app, I wanted post property rent give opt...
# Housing-Real Estate & Property  I property business got link SMS happy perform...
# Housing-Real Estate & Property  Useless app, I searched flats kondapur, Hydera...
#
#                                Sentiment  Sentiment_Polarity  \
# App
# Housing-Real Estate & Property  Negative           -0.400000
# Housing-Real Estate & Property  Positive            0.233333
# Housing-Real Estate & Property   Neutral            0.000000
# Housing-Real Estate & Property  Negative           -0.377778
# Housing-Real Estate & Property  Positive            0.021591
# Housing-Real Estate & Property  Positive            0.173333
# Housing-Real Estate & Property  Positive            0.225000
# Housing-Real Estate & Property  Negative           -0.287500
# Housing-Real Estate & Property  Positive            0.800000
# Housing-Real Estate & Property  Negative           -0.316667
#
#                                 Sentiment_Subjectivity
# App
# Housing-Real Estate & Property                0.250000
# Housing-Real Estate & Property                0.550000
# Housing-Real Estate & Property                0.000000
# Housing-Real Estate & Property                0.533333
# Housing-Real Estate & Property                0.259470
# Housing-Real Estate & Property                0.486667
# Housing-Real Estate & Property                0.447222
# Housing-Real Estate & Property                0.250000
# Housing-Real Estate & Property                1.000000
# Housing-Real Estate & Property                0.400000
